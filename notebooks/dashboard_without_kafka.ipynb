# %%
import os
os.chdir("/Users/Kuba/Library/CloudStorage/OneDrive-SGH/SGH/Rok IV/Analiza danych w czasie rzeczywistym/internet-of-trams")

from internet_of_trams.frontend.trams_dasahboard_job import TramsDashboardJob
from internet_of_trams.utils.get_config import get_config

# %%
job = TramsDashboardJob(
    ztm_api_key="12b8f222-5689-4177-9ac2-01ff1229c098",
    database_password="my-secret-pw")

await job.get_static_data()

# %%
job.show_trams([17, 33, 22])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_458ebe33afe4b41dfa1509db5dc78536 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_458ebe33afe4b41dfa1509db5dc78536&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_458ebe33afe4b41dfa1509db5dc78536 = L.map(
#                 &quot;map_458ebe33afe4b41dfa1509db5dc78536&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_06d825890fe0795c367c1737f686ccec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_06d825890fe0795c367c1737f686ccec.addTo(map_458ebe33afe4b41dfa1509db5dc78536);
#
#
#             var marker_c2726af757a64d9851bd08c276455132 = L.marker(
#                 [52.284065, 20.955788],
#                 {}
#             ).addTo(map_458ebe33afe4b41dfa1509db5dc78536);
#
#
#             var icon_c271386d53e15d795ff475923f806409 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c2726af757a64d9851bd08c276455132.setIcon(icon_c271386d53e15d795ff475923f806409);
#
#
#         var popup_075ef93945c33a52de12513897d9d1f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1cbf70cfd95f07bf4c148f75ccd69358 = $(`&lt;div id=&quot;html_1cbf70cfd95f07bf4c148f75ccd69358&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;style&gt;         .leaflet-popup-content-wrapper {             width: 200px;         }         &lt;/style&gt;     &lt;p&gt;vehicle_id: 3121&lt;/p&gt; &lt;p&gt;line: 17&lt;/p&gt; &lt;p&gt;date: 2024-04-13&lt;/p&gt; &lt;p&gt;time: 11:48:05&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_075ef93945c33a52de12513897d9d1f2.setContent(html_1cbf70cfd95f07bf4c148f75ccd69358);
#
#
#
#         marker_c2726af757a64d9851bd08c276455132.bindPopup(popup_075ef93945c33a52de12513897d9d1f2)
#         ;
#
#
#
#
#             var marker_6d41d6425de1091d0ee17a691c69df4e = L.marker(
#                 [52.232086, 20.99882],
#                 {}
#             ).addTo(map_458ebe33afe4b41dfa1509db5dc78536);
#
#
#             var icon_322846fd05613703f90d6b3bd4d9baef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6d41d6425de1091d0ee17a691c69df4e.setIcon(icon_322846fd05613703f90d6b3bd4d9baef);
#
#
#         var popup_fbc132a36b6256d6d2b217357cb0b7ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a0c3186f731f3fee86b2800e9edb0213 = $(`&lt;div id=&quot;html_a0c3186f731f3fee86b2800e9edb0213&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;style&gt;         .leaflet-popup-content-wrapper {             width: 200px;         }         &lt;/style&gt;     &lt;p&gt;vehicle_id: 3225&lt;/p&gt; &lt;p&gt;line: 17&lt;/p&gt; &lt;p&gt;date: 2024-04-13&lt;/p&gt; &lt;p&gt;time: 11:48:08&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_fbc132a36b6256d6d2b217357cb0b7ec.setContent(html_a0c3186f731f3fee86b2800e9edb0213);
#
#
#
#         marker_6d41d6425de1091d0ee17a691c69df4e.bindPopup(popup_fbc132a36b6256d6d2b217357cb0b7ec)
#         ;
#
#
#
#
#             var marker_79330e2cb0743cb22492fec7dc127612 = L.marker(
#                 [52.2199, 21.004929],
#                 {}
#             ).addTo(map_458ebe33afe4b41dfa1509db5dc78536);
#
#
#             var icon_35a92595807f53a55a6d24fc084f8709 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_79330e2cb0743cb22492fec7dc127612.setIcon(icon_35a92595807f53a55a6d24fc084f8709);
#
#
#         var popup_a18d57cc2e2483ee125f9e422a506f20 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_76e27aa2ab0a49703768fe89fc68e4b3 = $(`&lt;div id=&quot;html_76e27aa2ab0a49703768fe89fc68e4b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;style&gt;         .leaflet-popup-content-wrapper {             width: 200px;         }         &lt;/style&gt;     &lt;p&gt;vehicle_id: 3235&lt;/p&gt; &lt;p&gt;line: 17&lt;/p&gt; &lt;p&gt;date: 2024-04-13&lt;/p&gt; &lt;p&g
