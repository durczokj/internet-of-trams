# %%
import os
os.chdir("/Users/Kuba/Library/CloudStorage/OneDrive-SGH/SGH/Rok IV/Analiza danych w czasie rzeczywistym/internet-of-trams") ### This needs to be replaced.

from internet_of_trams.frontend.trams_dasahboard_job import TramsDashboardJob
from internet_of_trams.utils.get_config import get_config

# %%
job = TramsDashboardJob(
    ztm_api_key="12b8f222-5689-4177-9ac2-01ff1229c098",
    database_password="my-secret-pw")

await job.get_static_data()

# %%
job.show_trams([17, 33, 22])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0c038dbfd6e1560df2cf6267d118a3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0c038dbfd6e1560df2cf6267d118a3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0c038dbfd6e1560df2cf6267d118a3b = L.map(
#                 &quot;map_c0c038dbfd6e1560df2cf6267d118a3b&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7a1a09194211d762700552f66c2f032 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f7a1a09194211d762700552f66c2f032.addTo(map_c0c038dbfd6e1560df2cf6267d118a3b);
#
#
#             var marker_39b73228ed6c284455393e699cb7e0fb = L.marker(
#                 [52.206856, 21.004145],
#                 {}
#             ).addTo(map_c0c038dbfd6e1560df2cf6267d118a3b);
#
#
#             var icon_2a6d1da96d47486f92883f43c3c5a2a6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_39b73228ed6c284455393e699cb7e0fb.setIcon(icon_2a6d1da96d47486f92883f43c3c5a2a6);
#
#
#         var popup_0657b9114a7a61cdd4a57c3b083b63ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_905931b34c3060f3dba95fd72af89cf0 = $(`&lt;div id=&quot;html_905931b34c3060f3dba95fd72af89cf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;style&gt;         .leaflet-popup-content-wrapper {             width: 200px;         }         &lt;/style&gt;     &lt;p&gt;vehicle_id: 1378&lt;/p&gt; &lt;p&gt;line: 17&lt;/p&gt; &lt;p&gt;date: 2024-04-16&lt;/p&gt; &lt;p&gt;time: 19:09:19&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_0657b9114a7a61cdd4a57c3b083b63ba.setContent(html_905931b34c3060f3dba95fd72af89cf0);
#
#
#
#         marker_39b73228ed6c284455393e699cb7e0fb.bindPopup(popup_0657b9114a7a61cdd4a57c3b083b63ba)
#         ;
#
#
#
#
#             var marker_6f9098640f4f398e3098b286f84405ad = L.marker(
#                 [52.340633, 20.950193],
#                 {}
#             ).addTo(map_c0c038dbfd6e1560df2cf6267d118a3b);
#
#
#             var icon_fa8258db797b02c60132f37bde819d78 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6f9098640f4f398e3098b286f84405ad.setIcon(icon_fa8258db797b02c60132f37bde819d78);
#
#
#         var popup_5238f9902a74854b45757d6c668b2827 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da4989f0569b1979899daa86ae02836c = $(`&lt;div id=&quot;html_da4989f0569b1979899daa86ae02836c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;style&gt;         .leaflet-popup-content-wrapper {             width: 200px;         }         &lt;/style&gt;     &lt;p&gt;vehicle_id: 1404&lt;/p&gt; &lt;p&gt;line: 17&lt;/p&gt; &lt;p&gt;date: 2024-04-16&lt;/p&gt; &lt;p&gt;time: 19:09:17&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_5238f9902a74854b45757d6c668b2827.setContent(html_da4989f0569b1979899daa86ae02836c);
#
#
#
#         marker_6f9098640f4f398e3098b286f84405ad.bindPopup(popup_5238f9902a74854b45757d6c668b2827)
#         ;
#
#
#
#
#             var marker_4480ef4713d6da19b09c83ddb3e2cb6d = L.marker(
#                 [52.18658, 21.00016],
#                 {}
#             ).addTo(map_c0c038dbfd6e1560df2cf6267d118a3b);
#
#
#             var icon_f28066acd265ad3e2c48575b378621cb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4480ef4713d6da19b09c83ddb3e2cb6d.setIcon(icon_f28066acd265ad3e2c48575b378621cb);
#
#
#         var popup_b0a643411bea6a40c909e536ab51406c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc8479ef0fd4d94488438331dfe9248b = $(`&lt;div id=&quot;html_dc8479ef0fd4d94488438331dfe9248b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;style&gt;         .leaflet-popup-content-wrapper {             width: 200px;         }         &lt;/style&gt;     &lt;p&gt;vehicle_id: 1458&lt;/p&gt; &lt;p&gt;line: 17&lt;/p&gt; &lt;p&gt;date: 2024-04-16&lt;/p&gt; &lt;p&
