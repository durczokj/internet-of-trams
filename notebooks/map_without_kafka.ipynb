# %%
import os
os.chdir("/Users/Kuba/Library/CloudStorage/OneDrive-SGH/SGH/Rok IV/Analiza danych w czasie rzeczywistym/internet-of-trams") ### This needs to be replaced.

from internet_of_trams.frontend.trams_dasahboard_job_copy import TramsDashboardJob
from internet_of_trams.utils.get_config import get_config

# %%
config = get_config()
job = TramsDashboardJob(
    ztm_api_key="12b8f222-5689-4177-9ac2-01ff1229c098",
    database_host=config["DATABASE_HOST"],
    database_port=config["DATABASE_PORT"],
    database_password=config["DATABASE_PASSWORD"])

await job.get_static_data()

# %%
job.get_map([17])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_538eac9bbb5e483e38a4d5572810dfba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_538eac9bbb5e483e38a4d5572810dfba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_538eac9bbb5e483e38a4d5572810dfba = L.map(
#                 &quot;map_538eac9bbb5e483e38a4d5572810dfba&quot;,
#                 {
#                     center: [52.2297, 21.0122],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: false,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1aa338208c2c587ddc38ed58df3cd22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 12, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d1aa338208c2c587ddc38ed58df3cd22.addTo(map_538eac9bbb5e483e38a4d5572810dfba);
#
#
#             var marker_7f8acf5ef758f6d913c28c33110ea334 = L.marker(
#                 [52.338436, 20.94357],
#                 {}
#             ).addTo(map_538eac9bbb5e483e38a4d5572810dfba);
#
#
#             var icon_3ab3021af517640412a53420d0251c03 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7f8acf5ef758f6d913c28c33110ea334.setIcon(icon_3ab3021af517640412a53420d0251c03);
#
#
#         var popup_516d24b7c205552e6b02e7fadcc83b50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b09192bc902b808dfa5b022318598c2 = $(`&lt;div id=&quot;html_6b09192bc902b808dfa5b022318598c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;style&gt;         .leaflet-popup-content-wrapper {             width: 200px;         }         &lt;/style&gt;     &lt;p&gt;vehicle_id: 3121&lt;/p&gt; &lt;p&gt;line: 17&lt;/p&gt; &lt;p&gt;date: 2024-05-19&lt;/p&gt; &lt;p&gt;time: 21:55:44&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_516d24b7c205552e6b02e7fadcc83b50.setContent(html_6b09192bc902b808dfa5b022318598c2);
#
#
#
#         marker_7f8acf5ef758f6d913c28c33110ea334.bindPopup(popup_516d24b7c205552e6b02e7fadcc83b50)
#         ;
#
#
#
#
#             var marker_37e08d0e0439f5ede6dcce921c5c658d = L.marker(
#                 [52.18714, 20.999199],
#                 {}
#             ).addTo(map_538eac9bbb5e483e38a4d5572810dfba);
#
#
#             var icon_5c7cae5ae3b71ce1886c8c2927b2d978 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_37e08d0e0439f5ede6dcce921c5c658d.setIcon(icon_5c7cae5ae3b71ce1886c8c2927b2d978);
#
#
#         var popup_dcf4be1f9b06617a4cb4a379dfaccba4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_90d22b9b967f489fa8b14e7c8b2530f4 = $(`&lt;div id=&quot;html_90d22b9b967f489fa8b14e7c8b2530f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;style&gt;         .leaflet-popup-content-wrapper {             width: 200px;         }         &lt;/style&gt;     &lt;p&gt;vehicle_id: 3128&lt;/p&gt; &lt;p&gt;line: 17&lt;/p&gt; &lt;p&gt;date: 2024-05-19&lt;/p&gt; &lt;p&gt;time: 20:20:06&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_dcf4be1f9b06617a4cb4a379dfaccba4.setContent(html_90d22b9b967f489fa8b14e7c8b2530f4);
#
#
#
#         marker_37e08d0e0439f5ede6dcce921c5c658d.bindPopup(popup_dcf4be1f9b06617a4cb4a379dfaccba4)
#         ;
#
#
#
#
#             var marker_28d9b4bb0d5b3530e498fc8564a0cb30 = L.marker(
#                 [52.299866, 20.929081],
#                 {}
#             ).addTo(map_538eac9bbb5e483e38a4d5572810dfba);
#
#
#             var icon_a61c5aa5c5a7222e2bbc83d286907c08 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_28d9b4bb0d5b3530e498fc8564a0cb30.setIcon(icon_a61c5aa5c5a7222e2bbc83d286907c08);
#
#
#         var popup_ca20d8a76611a6a5e48396cd3ef03f43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a02a22f5cffd7349ddf0b5febd13038f = $(`&lt;div id=&quot;html_a02a22f5cffd7349ddf0b5febd13038f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;style&gt;         .leaflet-popup-content-wrapper {             width: 200px;         }         &lt;/style&gt;     &lt;p&gt;vehicle_id: 3139&lt;/p&gt; &lt;p&gt;line: 17&lt;/p&gt; &lt;p&gt;date: 2024-05-19&lt;/p&gt; &lt;
